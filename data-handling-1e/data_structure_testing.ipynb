# %% [markdown]
# # Data structure testing

# %% [markdown]
# ## Authors:
#  - Nathaniel Patterson

# %% [markdown]
# ### Data Types
# - [ ]  Arrays
# - [ ] Records
# - [ ] Dictionaries

# %% [markdown]
# Below is the code to import the different stuff

# %%
#import stuff
import time
import pandas as pd
import os
import glob
import string
import time
import matplotlib.pyplot as plt
import numpy as np
import os.path
import os.path
import random

# %% [markdown]
# ## Read/Write speed tester:

# %%
import time
import glob

import time
import pandas as pd
import os
import glob
import string
import time
import matplotlib.pyplot as plt
import numpy as np
import os.path
import os.path
import random
x = random.randint(1,1000)

files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')



#code to open file goes here
start_time = time.time()

#read speed test goes here
datalist = []
for x in range(len(files)):
    input_data = pd.read_csv(files[x])
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
    print(dataframe)
    datalist.append(dataframe)

end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time

start_time = time.time()
   
#Write speed test goes here
save_path = 'C:\\Users\\jde35739\\Desktop\\testdata'
name_of_file = ("datafile"+str(x))

completeName = os.path.join(save_path, name_of_file+".txt")         
file1 = open(completeName, "w")
toFile = str(datalist)
print(datalist)
file1.write(toFile)
file1.close()


end_time = time.time()
total_time = (round(end_time - start_time, 11))
print('Results:')
print()
print('Read Time:',readtime)
print('Write Time:',total_time)
# Out:
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-6.70999987e-03 -4.87999991e-03 -4.26999992e-03 ... -5.48999989e-03
#   -4.87999991e-03 -4.26999992e-03]
#  [-3.04999994e-03  6.09999988e-04  1.21999998e-03 ...  4.26999992e-03
#    4.26999992e-03  6.09999988e-04]
#  ...
#  [-3.04999994e-03  1.21999998e-03  2.43999995e-03 ...  2.43999995e-03
#   -1.21999998e-03  0.00000000e+00]
#  [-1.21999998e-03 -1.21999998e-03  6.09999988e-04 ... -6.70999987e-03
#   -4.87999991e-03 -4.87999991e-03]
#  [ 3.53999995e-02  3.53999995e-02  3.60100009e-02 ...  2.31899992e-02
#    2.31899992e-02  2.31899992e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-4.26999992e-03 -6.09999988e-03 -4.26999992e-03 ... -4.87999991e-03
#   -4.87999991e-03 -4.87999991e-03]
#  [-6.09999988e-03 -3.65999993e-03 -3.65999993e-03 ...  5.48999989e-03
#    3.04999994e-03  3.65999993e-03]
#  ...
#  [-1.21999998e-03  6.09999988e-04  0.00000000e+00 ...  6.09999988e-04
#   -6.09999988e-04  6.09999988e-04]
#  [ 0.00000000e+00 -6.09999988e-04  0.00000000e+00 ... -1.82999996e-03
#   -1.21999998e-03 -1.82999996e-03]
#  [ 3.47900018e-02  3.53999995e-02  3.53999995e-02 ...  2.25799996e-02
#    2.19700001e-02  2.13600006e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-4.87999991e-03 -4.87999991e-03 -4.26999992e-03 ... -6.09999988e-03
#   -6.09999988e-03 -4.87999991e-03]
#  [-6.09999988e-04  6.09999988e-04  1.21999998e-03 ...  1.21999998e-03
#    1.82999996e-03  1.21999998e-03]
#  ...
#  [-1.82999996e-03  1.82999996e-03  4.87999991e-03 ... -6.09999988e-04
#    1.21999998e-03 -1.21999998e-03]
#  [-6.09999988e-04  0.00000000e+00  1.82999996e-03 ... -1.21999998e-03
#   -1.21999998e-03 -5.48999989e-03]
#  [ 3.66199985e-02  3.66199985e-02  3.72299999e-02 ...  2.38000005e-02
#    2.25799996e-02  2.25799996e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [
#        [-1.21999998e-03,  1.82999996e-03,  1.21999998e-03, ...,
#          1.21999998e-03,  6.09999988e-04,  1.21999998e-03],
#        [-2.43999995e-03, -4.26999992e-03, -2.43999995e-03, ...,
#         -5.48999989e-03, -4.87999991e-03, -2.43999995e-03],
#        [ 3.41800004e-02,  3.41800004e-02,  3.60100009e-02, ...,
#          2.13600006e-02,  2.13600006e-02,  2.13600006e-02]])]
# Results:
#
# Read Time: 2.81322979927
# Write Time: 0.0230152607

# %% [markdown]
# Below is the example code given to us from the example

# %%
#Example Code from example
'''
import glob
import pandas as pd
#import random
#import paho.mqtt.client as mqtt
import string
import time
import matplotlib.pyplot as plt
import numpy as np

files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
for file in files:
    print(file)

selected_file = files[0]
input_data = pd.read_csv(selected_file)
dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
x_data = np.linspace(-0.5, 10.5, 2200)

plt.scatter(x_data, dataframe[39]);
plt.title('R5IM');
plt.xlabel('Time [ms]');
plt.ylabel('Signal [V]');
plt.grid()
'''

'''
plt.scatter(x_data, dataframe[38]);
plt.title('R9BLM4');
plt.xlabel('Time [ms]');
plt.ylabel('Signal [V]');
plt.grid()

plt.scatter(x_data, dataframe[38]);
plt.title('R9BLM4');
plt.xlabel('Time [ms]');
plt.ylabel('Signal [V]');
plt.grid()

'''
'''
files = glob.glob("BLM_R5IM_Data/R5IM_loss" + '/*.csv')
selected_file = files[0]
input_data = pd.read_csv(selected_file)
dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
plt.scatter(x_data, dataframe[39]);
plt.title('R5IM');
plt.xlabel('Time [ms]');
plt.ylabel('Signal [V]');
plt.grid()
'''

# %% [markdown]
# Here is a testing area for some code

# %%
#datafile = pd.read_csv('mydata.csv')
import time
files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
print(files[0])



for x in range(len(files)):
    input_data = pd.read_csv(files[x])
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
    print(dataframe)

    
    

'''
import csv
import numpy
result_list = list(files[0])
print(result_list)
result_2D = numpy.array(result_list)

print(result_2D)
'''

# %% [markdown]
# To test the speed of the read and write of different data strucutres, here is simple code for a timer

# %%
start_time = time.time()
end_time = time.time()
total_time = (round(end_time - start_time, 4))
print('Time:',total_time)

# %% [markdown]
# Now, to adapt this timer to test read and write speed:

# %%
#time stalling code to test timer
for x in range(1,1000000):
    y = x**2

# %%
import time
import glob

#code to open file goes here
#read speed test
start_time = time.time()

#read speed test

end_time = time.time()
total_time = (round(end_time - start_time, 11))
print('Read Time:',total_time)

#write speed test
start_time = time.time()
    
end_time = time.time()
total_time = (round(end_time - start_time, 11))
print('Write Time:',total_time)

#yay it works

# %% [markdown]
# Now to do a similar thing to earlier using os instead of panda to see whether this is faster. Does not work at the moment

# %%
import os
path = "C:\Users\jde35739\Desktop\data-handling-1e\BLM_R5IM_Data"
dir_list = os.listdir(path)
  
print("Files and directories in '", path, "' :") 
  
# print the list
print(dir_list)

# %% [markdown]
# Here I want to remake the code using regular python file code

# %% [markdown]
# Working on code to write files

# %%
import time
import pandas as pd
import os
import glob
import string
import time
import matplotlib.pyplot as plt
import numpy as np
import os.path
import os.path
import random
x = random.randint(1,1000)

files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
print(files[0])


datalist = []
for x in range(len(files)):
    input_data = pd.read_csv(files[x])
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
    print(dataframe)
    datalist.append(dataframe)

#replace the save path with the save path you want
save_path = 'C:\\Users\\jde35739\\Desktop\\testdata'
name_of_file = ("datafile"+str(x))

completeName = os.path.join(save_path, name_of_file+".csv")         
file1 = open(completeName, "w")
toFile = str(datalist)
print(datalist)
file1.write(toFile)
file1.close()
# Out:
# BLM_R5IM_Data/cycle\26_05_2023_00_35_36_034042.csv
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-6.70999987e-03 -4.87999991e-03 -4.26999992e-03 ... -5.48999989e-03
#   -4.87999991e-03 -4.26999992e-03]
#  [-3.04999994e-03  6.09999988e-04  1.21999998e-03 ...  4.26999992e-03
#    4.26999992e-03  6.09999988e-04]
#  ...
#  [-3.04999994e-03  1.21999998e-03  2.43999995e-03 ...  2.43999995e-03
#   -1.21999998e-03  0.00000000e+00]
#  [-1.21999998e-03 -1.21999998e-03  6.09999988e-04 ... -6.70999987e-03
#   -4.87999991e-03 -4.87999991e-03]
#  [ 3.53999995e-02  3.53999995e-02  3.60100009e-02 ...  2.31899992e-02
#    2.31899992e-02  2.31899992e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-4.26999992e-03 -6.09999988e-03 -4.26999992e-03 ... -4.87999991e-03
#   -4.87999991e-03 -4.87999991e-03]
#  [-6.09999988e-03 -3.65999993e-03 -3.65999993e-03 ...  5.48999989e-03
#    3.04999994e-03  3.65999993e-03]
#  ...
#  [-1.21999998e-03  6.09999988e-04  0.00000000e+00 ...  6.09999988e-04
#   -6.09999988e-04  6.09999988e-04]
#  [ 0.00000000e+00 -6.09999988e-04  0.00000000e+00 ... -1.82999996e-03
#   -1.21999998e-03 -1.82999996e-03]
#  [ 3.47900018e-02  3.53999995e-02  3.53999995e-02 ...  2.25799996e-02
#    2.19700001e-02  2.13600006e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-4.87999991e-03 -4.87999991e-03 -4.26999992e-03 ... -6.09999988e-03
#   -6.09999988e-03 -4.87999991e-03]
#  [-6.09999988e-04  6.09999988e-04  1.21999998e-03 ...  1.21999998e-03
#    1.82999996e-03  1.21999998e-03]
#  ...
#  [-1.82999996e-03  1.82999996e-03  4.87999991e-03 ... -6.09999988e-04
#    1.21999998e-03 -1.21999998e-03]
#  [-6.09999988e-04  0.00000000e+00  1.82999996e-03 ... -1.21999998e-03
#   -1.21999998e-03 -5.48999989e-03]
#  [ 3.66199985e-02  3.66199985e-02  3.72299999e-02 ...  2.38000005e-02
#    2.25799996e-02  2.25799996e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [-4.87999991e-03 -6.09999988e-03 -4.87999991e-03 ... -6.09999988e-03
#   -5.48999989e-03 -5.48999989e-03]
#  [-7.93000031e-03 -6.09999988e-03 -2.43999995e-03 ...  4.26999992e-03
#    3.65999993e-03  1.21999998e-03]
#  ...
#  [ 6.09999988e-04  0.00000000e+00  2.43999995e-03 ... -6.09999988e-04
#   -6.09999988e-04  6.09999988e-04]
#  [-2.43999995e-03 -6.09999988e-04 -1.82999996e-03 ... -2.43999995e-03
#   -1.82999996e-03 -4.26999992e-03]
#  [ 3.23500000e-02  3.41800004e-02  3.53999995e-02 ...  2.07499992e-02
#    2.13600006e-02  2.19700001e-02]]
# [[-4.99939013e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [

# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 30
#      27 name_of_file = ("datafile"+str(x))
#      29 completeName = os.path.join(save_path, name_of_file+".csv")
# ---> 30 file1 = open(completeName, "w")
#      31 toFile = str(datalist)
#      32 print(datalist)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\jde35739\\Desktop\\testdata\\datafile17.csv'

# %% [markdown]
# Tom's Code with pyarrow:

# %%
import glob
import pandas as pd
import csv
import time

start_time = time.time() 
for x in range(0,10):
    files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
    selected_file = files[0]
    input_data = pd.read_csv(selected_file)
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
 
end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("Writetime ",readtime)
start_time = time.time()

#print(dataframe)

for x in range(1,400):
    f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.txt", "w")
    writer = csv.writer(f)
    writer.writerows(dataframe)
    f.close()

print(dataframe[0])


end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("File time ",readtime)
finaltime = readtime + total_time
print("Total time ",finaltime)


'''
f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.txt", "r")
reader = csv.reader(f)
i = 0
for line in reader:
    voltage = (line)
    #voltage = (line)
    dataframe[i] = voltage
    i += 1;
f.close()

print(dataframe)
'''
# Out:
# Writetime  1.68849945068
# [-4.99939013 -4.99939013 -4.99939013 ... -4.99939013 -4.99939013
#  -4.99939013]
# File time  85.71537065506
# Total time  171.43074131012
# '\nf = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.txt", "r")\nreader = csv.reader(f)\ni = 0\nfor line in reader:\n    voltage = (line)\n    #voltage = (line)\n    dataframe[i] = voltage\n    i += 1;\nf.close()\n\nprint(dataframe)\n'

# %% [markdown]
# now with csv

# %%
import glob
import pandas as pd
import csv
import time

start_time = time.time() 
for x in range(0,10):
    files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
    selected_file = files[0]
    input_data = pd.read_csv(selected_file)
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
 
end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("Writetime ",readtime)
start_time = time.time()

#print(dataframe)

for x in range(1,400):
    f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.csv", "w")
    writer = csv.writer(f)
    writer.writerows(dataframe)
    f.close()

print(dataframe[0])


end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("File time ",readtime)
finaltime = readtime + total_time
print("Total time ",finaltime)


'''
f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.csv", "r")
reader = csv.reader(f)
i = 0
for line in reader:
    voltage = (line)
    #voltage = (line)
    dataframe[i] = voltage
    i += 1;
f.close()

print(dataframe)
'''
# Out:
# Writetime  1.11901116371
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 22
#      19 #print(dataframe)
#      21 for x in range(1,400):
# ---> 22     f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.csv", "w")
#      23     writer = csv.writer(f)
#      24     writer.writerows(dataframe)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\jde35739\\Documents\\testdatafolder\\cnewone.csv'

# %% [markdown]
# Now tested again without pyarrow

# %%
import glob
import pandas as pd
import csv
import time

start_time = time.time() 
for x in range(0,10):
    files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
    selected_file = files[0]
    input_data = pd.read_csv(selected_file)
    dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
 
end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("Writetime ",readtime)
start_time = time.time()

#print(dataframe)

for x in range(0,10):
    f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\csvBLM.csv", "w")
    writer = csv.writer(f)
    writer.writerows(dataframe)
    f.close()

print(dataframe[0])

end_time = time.time()
total_time = (round(end_time - start_time, 11))
readtime = total_time
print("File time ",readtime)
finaltime = readtime + total_time
print("Total time ",finaltime)


'''
f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\csvBLM.csv", "r")
reader = csv.reader(f)
i = 0
for line in reader:
    voltage = (line)
    #voltage = (line)
    dataframe[i] = voltage
    i += 1;
f.close()

print(dataframe)
'''
# Out:
# Writetime  1.16794490814
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 22
#      19 #print(dataframe)
#      21 for x in range(0,10):
# ---> 22     f = open("C:\\Users\\jde35739\\Documents\\testdatafolder\\csvBLM.csv", "w")
#      23     writer = csv.writer(f)
#      24     writer.writerows(dataframe)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\jde35739\\Documents\\testdatafolder\\csvBLM.csv'

# %%
import numpy as np
import glob

'''
files = glob.glob("BLM_R5IM_Data/cycle" + '/*.csv')
selected_file = files[0]
input_data = pd.read_csv(selected_file)
dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()


file = open("data.csv")
 
for i in file:
    print(i)
'''


files = glob.glob("C:\\Users\\jde35739\\Desktop\\data-handling-1e\\BLM_R5IM_Data")
selected_file = (files[0])
array = np.loadtxt(selected_file, delimiter=',')
print(array)
selected_file.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 20
#      18 files = glob.glob("C:\\Users\\jde35739\\Desktop\\data-handling-1e\\BLM_R5IM_Data")
#      19 selected_file = (files[0])
# ---> 20 array = np.loadtxt(selected_file, delimiter=',')
#      21 print(array)
#      22 selected_file.close()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\numpy\lib\npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339             converters=converters, skiplines=skiprows, usecols=usecols,
#    1340             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1341             max_rows=max_rows, quote=quotechar)
#    1343 return arr
#
# File ~\AppData\Local\anaconda3\lib\site-packages\numpy\lib\npyio.py:975, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     973     fname = os.fspath(fname)
#     974 if isinstance(fname, str):
# --> 975     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     976     if encoding is None:
#     977         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\numpy\lib\_datasource.py:530, in DataSource.open(self, path, mode, encoding, newline)
#     528     if ext == 'bz2':
#     529         mode.replace("+", "")
# --> 530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
#     533     raise FileNotFoundError(f"{path} not found.")
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\jde35739\\Desktop\\data-handling-1e\\BLM_R5IM_Data'

# %%
def loaddata(data):
# Out:
#   Cell In[4], line 1
#     def #insertname(#insertvariables):
#         ^
# SyntaxError: invalid syntax

# %%
import polars
import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import polars
#       2 import glob
#
# ModuleNotFoundError: No module named 'polars'

# %% [markdown]
# Polars Reading speed testing

# %%
import polars as pl
import numpy
import time


files = glob.glob("C:\\Users\\jde35739\\Desktop\\data-handling-1e\\BLM_R5IM_Data\\R5IM_loss//28_05_2023_23_02_08_858925.csv")
selected_file = (files[0])  

start_time = time.time()

df = pl.read_csv(selected_file)
#print(df)
print(df.to_numpy())


end_time = time.time()
total_time = (round(end_time - start_time, 11))
print("Read Time ",total_time)
# Out:
# [[ 0.00000000e+00 -4.99939013e+00 -4.99939013e+00 ... -4.99939013e+00
#   -4.99939013e+00 -4.99939013e+00]
#  [ 1.00000000e+00 -3.65999993e-03 -3.65999993e-03 ... -4.87999991e-03
#   -3.65999993e-03 -4.26999992e-03]
#  [ 2.00000000e+00 -6.09999988e-04  1.82999996e-03 ...  7.31999986e-03
#    6.70999987e-03  4.26999992e-03]
#  ...
#  [ 3.70000000e+01  6.09999988e-04  1.21999998e-03 ...  6.09999988e-04
#    0.00000000e+00  2.43999995e-03]
#  [ 3.80000000e+01  1.82999996e-03  0.00000000e+00 ... -6.09999988e-04
#   -1.21999998e-03  6.09999988e-04]
#  [ 3.90000000e+01  4.69999984e-02  4.69999984e-02 ... -9.58300009e-02
#   -9.39899981e-02 -9.45999995e-02]]
# Read Time  0.04407095909

# %% [markdown]
# Date/time code for files.

# %%
import datetime

current_Time = '{date:%d_%m_%Y_%H_%M_%S_%f}'.format( date=datetime.datetime.now())



print(str(current_Time))
# Out:
# 30_06_2023_13_42_58_910641

# %% [markdown]
# Here we need to create code to load and print different data structures
