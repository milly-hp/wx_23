# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import animation

fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
# ax = plt.axes(xlim=(0, 2), ylim=(0, 100))

N = 4
lines = [plt.plot([], [])[0] for _ in range(N)] #lines to animate
rectangles = plt.bar([0.5,1,1.5], [50,40,90],width=0.1) #rectangles to animate
patches = lines + list(rectangles) #things to animate

def init():
    #init lines
    
    
    for line in lines:
        line.set_data([], [])
    #init rectangles
    
    for rectangle in rectangles:
        rectangle.set_height(2)
    return patches #return everything that must be updated

def animate(i):
    #animate lines
    for j,line in enumerate(lines):
        line.set_data([0, 2], [10 * j,i], [0, 2])
        
    #animate rectangles
    for j,rectangle in enumerate(rectangles):
        rectangle.set_height(i/(j+1))
    return patches #return everything that must be updated

anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 36
#      33         rectangle.set_height(i/(j+1))
#      34     return patches #return everything that must be updated
# ---> 36 anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)
#      37 plt.show()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:1686, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1683 # Needs to be initialized so the draw functions work without checking
#    1684 self._save_seq = []
# -> 1686 super().__init__(fig, **kwargs)
#    1688 # Need to reset the saved seq, since right now it will contain data
#    1689 # for a single frame from init, which is not what we want.
#    1690 self._save_seq = []
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:1408, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1406 if event_source is None:
#    1407     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1408 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:876, in Animation.__init__(self, fig, event_source, blit)
#     873 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     874                                               self._stop)
#     875 if self._blit:
# --> 876     self._setup_blit()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:1201, in Animation._setup_blit(self)
#    1199 self._drawn_artists = []
#    1200 # _post_draw needs to be called first to initialize the renderer
# -> 1201 self._post_draw(None, self._blit)
#    1202 # Then we need to clear the Frame for the initial draw
#    1203 # This is typically handled in _on_resize because QT and Tk
#    1204 # emit a resize event on launch, but the macosx backend does not,
#    1205 # thus we force it here for everyone for consistency
#    1206 self._init_draw()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:1156, in Animation._post_draw(self, framedata, blit)
#    1154     self._blit_draw(self._drawn_artists)
#    1155 else:
# -> 1156     self._fig.canvas.draw_idle()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2078, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2076 if not self._is_idle_drawing:
#    2077     with self._idle_draw_cntx():
# -> 2078         self.draw(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\figure.py:3135, in Figure.draw(self, renderer)
#    3132 finally:
#    3133     self.stale = False
# -> 3135 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:900, in Animation._start(self, *args)
#     897 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     899 # Now do any initial draw
# --> 900 self._init_draw()
#     902 # Add our callback for stepping the animation and
#     903 # actually start the event_source.
#     904 self.event_source.add_callback(self._step)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\matplotlib\animation.py:1742, in FuncAnimation._init_draw(self)
#    1740     self._draw_frame(frame_data)
#    1741 else:
# -> 1742     self._drawn_artists = self._init_func()
#    1743     if self._blit:
#    1744         if self._drawn_artists is None:
#
# Cell In[7], line 23, in init()
#      20 #init rectangles
#      22 for rectangle in rectangles:
# ---> 23     rectangle.set_height(2)
#      24 return patches
#
# AttributeError: 'Patch3D' object has no attribute 'set_height'

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 10
#       5 import time
#       7 files = glob.glob("BLM_R5IM_Data\\cycle" + '/*.csv')
# ---> 10 selected_file = files[0]
#      11 input_data = pd.read_csv(selected_file)
#      12 dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
#
# IndexError: list index out of range

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 files = glob.glob("BLM_R5IM_Data\\cycle" + '/*.csv')
# ----> 4 selected_file = files[0]
#       5 input_data = pd.read_csv(selected_file)
#       6 dataframe = input_data.drop(columns = input_data.columns[0]).to_numpy()
#
# IndexError: list index out of range
